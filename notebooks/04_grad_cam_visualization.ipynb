# %%
import sys
sys.path.append("../src")

# %load_ext autoreload
# %autoreload 2

import torch
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from data_loader import get_data_loaders
from model import get_resnet18
from train import train_model
from evaluate import evaluate_model
from grad_cam import GradCAM
from utils import save_model, load_model, predict_image

# %%
import os
image_dir = "../dataset/test/glioma"
print("Files in glioma test folder:")
print(os.listdir(image_dir))
# Out:
# Files in glioma test folder:
# ...

# %%
from PIL import Image
import os

image_path = "../dataset/test/glioma/Te-gl_0010.jpg"

if os.path.exists(image_path):
    image = Image.open(image_path).convert("RGB")
    print("✅ Image loaded successfully.")
    image.show()  
else:
    print(f"❌ File not found: {image_path}")
# Out:
# ✅ Image loaded successfully.

# %%
import matplotlib.pyplot as plt

plt.imshow(image)
plt.title("MRI Scan")
plt.axis("off")
plt.show()

# %%
import glob

test_images = glob.glob("../dataset/test/*/*.jpg")[:5]  
for img in test_images:
    print(img)
# Out:
# ../dataset/test\glioma\Te-gl_0010.jpg
# ../dataset/test\glioma\Te-gl_0011.jpg
# ../dataset/test\glioma\Te-gl_0012.jpg
# ../dataset/test\glioma\Te-gl_0013.jpg
# ../dataset/test\glioma\Te-gl_0014.jpg
